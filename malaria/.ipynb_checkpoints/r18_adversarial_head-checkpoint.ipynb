# %% [markdown]
# # Implementation of Stand Alone Self Attention For Malaria Parasite Detection in Blood Smears
# ---
# This notebook trains the image classification model and implements Guide Grad CAM to help explain the predictions of the model.
#
# ![Stand Alone SA module](sasa.png)

# %%
from fastai.vision.all import *
from sklearn.metrics import auc, roc_curve, precision_recall_curve, classification_report

# %% [markdown]
# ## Relative Self Attention Module

# %%
class RelativeSelfAttention(Module):
    def __init__(self, d_in, d_out, ks, groups, stride=1):
        self.n_c, self.ks, self.groups, self.stride = d_out, ks, groups, stride
        # linear transformation for queries, values and keys
        self.qx, self.kx, self.vx = [ConvLayer(d_in, d_out, ks=1, norm_type=None,
                                               act_cls=None) for _ in range(3)]
        # positional embeddings
        self.row_embeddings = nn.Parameter(torch.randn(d_out//2, ks))
        self.col_embeddings = nn.Parameter(torch.randn(d_out//2, ks))
        
    def calc_out_shape(self, inp_shape, pad):
        out_shape = [(sz + 2*pad - self.ks) // self.stride + 1 for sz in inp_shape]
        return out_shape
    
    def forward(self, x):
        query, keys, values = self.qx(x), self.kx(x), self.vx(x)
        
        pad = (self.ks -1) // 2
        
        # use unfold to extract the memory blocks and their associated queries
        query = F.unfold(query, kernel_size=1, stride=self.stride)
        keys = F.unfold(keys, kernel_size=self.ks, padding=pad, stride=self.stride)
        values = F.unfold(values, kernel_size=self.ks, padding=pad, stride=self.stride)
        
        
        # reshape and permute the dimensions into the appropriate format for matrix multiplication
        query = query.view(query.shape[0], self.groups, self.n_c//self.groups, -1, query.shape[-1]) # bs*G*C//G*1*N
        query = query.permute(0, 4, 1, 2, 3) # bs * N * G * C//G * 1
        keys = keys.view(keys.shape[0], self.groups, self.n_c//self.groups, -1, keys.shape[-1]) # bs*G*C//G*ks^2*N
        keys = keys.permute(0, 4, 1, 2, 3) # bs * N * G * C//G * ks^2
        values = values.view(values.shape[0], self.groups, self.n_c//self.groups, -1, values.shape[-1]) # bs*G*C//G*ks^2*N
        values = values.permute(0, 4, 1, 2, 3) # bs * N * G * C//G * ks^2
        
        # get positional embeddings
        row_embeddings = self.row_embeddings.unsqueeze(-1).expand(-1, -1, self.ks)
        col_embeddings = self.col_embeddings.unsqueeze(-2).expand(-1, self.ks, -1)
        
        embeddings = torch.cat((row_embeddings, col_embeddings)).view(self.groups,
                                self.n_c//self.groups, -1) # G * C//G * ks^2
        # add empty dimensions to match the shape of keys
        embeddings = embeddings[None, None, -1] # 1 * 1 * G * C//G * ks^2
        
        # compute attention map
        att_map = F.softmax(torch.matmul(query.transpose(-2,-1), keys+embeddings).contiguous(), dim=-1)
        # compute final output
        out = torch.matmul(att_map, values.transpose(-2,-1)).contiguous().permute(0, 2, 3, 4, 1)
        
        return out.view(out.shape[0], self.n_c, *self.calc_out_shape(x.shape[-2:], pad)).contiguous()

# %% [markdown]
# ## Define helper functions and modules

# %%
def resnet_stem(*sizes):
    return [
        ConvLayer(sizes[i], sizes[i+1], stride=2 if i==0 else 1)
         for i in range(len(sizes) - 1)
    ] + [nn.MaxPool2d(kernel_size=3, stride=2, padding=1)]

# %%
def bottleneck(ni, nf, stride):
    if stride==1:
        layers = [ConvLayer(ni, nf//4, ks=1),
              RelativeSelfAttention(nf//4, nf//4, ks=7, groups=8),
              ConvLayer(nf//4, nf, ks=1, act_cls=None, norm_type=NormType.BatchZero)]
    else:
        layers = [ConvLayer(ni, nf//4, ks=1),
              RelativeSelfAttention(nf//4, nf//4, ks=7, groups=8),
              nn.AvgPool2d(2, ceil_mode=True),
              ConvLayer(nf//4, nf, ks=1, act_cls=None, norm_type=NormType.BatchZero)]
    
    return nn.Sequential(*layers)

# %%
class ResNetBlock(Module):
    def __init__(self, ni, nf, stride, sa, expansion=1):
        self.botl = bottleneck(ni, nf, stride)
        self.idconv = noop if ni==nf else ConvLayer(ni, nf, 1, act_cls=None)
        self.pool = noop if stride==1 else nn.AvgPool2d(2, ceil_mode=True)
        
    def forward(self, x):
        return F.relu(self.botl(x) + self.idconv(self.pool(x)))

# %% [markdown]
# ## Define Randomization Layer to Protect Against Adversarial Attacks

# %%
class RandHead(Module):
    def __init__(self):
        pass
        
    def forward(self, x):
        rz_shape = torch.randint(210, 224, (1,))
        pad = (224 - rz_shape).item()
        h = torch.randint(0, pad+1, (1,))
        w = torch.randint(0, pad+1, (1,))
        
        # step 1 random resize
        out = F.interpolate(x, [rz_shape]*2)
        # step 2 pad
        return F.pad(out, (h, pad-h, w, pad-w))

# %% [markdown]
# ## Define ResNet module

# %%
class xResNet(nn.Sequential):
    def __init__(self, channels, n_out, blocks, sa=True, expansion=1):
        stem = resnet_stem(channels, 32, 32, 64)
        self.group_sizes = [64, 64, 128, 256, 512]
        for i in range(1, len(self.group_sizes)): 
            self.group_sizes[i] *= expansion
        groups = [self._make_group(idx, n_blocks, sa=sa if idx==0 else False) 
                      for idx, n_blocks in enumerate(blocks)]
        
        super().__init__(RandHead(), *stem, *groups,
                         nn.AdaptiveAvgPool2d(1), Flatten(),
                         nn.Linear(self.group_sizes[-1], n_out))
        
    def _make_group(self, idx, n_blocks, sa):
        stride = 1 if idx==1 else 2
        ni, nf = self.group_sizes[idx], self.group_sizes[idx+1]
        return nn.Sequential(*[
            ResNetBlock(ni if i==0 else nf, nf, stride=stride if i==0 else 1,
                        sa=sa if i==n_blocks-1 else False)
             for i in range(n_blocks)
        ])

# %% [markdown]
# ## Get the data

# %%
path = Path('data/')
Path.BASE_PATH = path
path.ls()
# Out:
# (#3) [Path('.ipynb_checkpoints'),Path('plasmodium-phonecamera'),Path('cell_images')]

# %%
imgs = get_image_files(path/'cell_images/cell_images')
img_sizes = L([Image.open(img).shape for img in imgs])

# %%
img_sizes
# Out:
# (#27558) [(151, 145),(112, 139),(133, 115),(148, 142),(109, 115),(160, 127),(136, 133),(160, 151),(136, 148),(145, 133)...]

# %%
h = []
w = []

for i in img_sizes:
    h.append(i[0])
    w.append(i[1])

# %%
plt.scatter(w, h)

# %%
def get_y(o):
    return [o.parent.name]

# %%
dblock = DataBlock(blocks=(ImageBlock, MultiCategoryBlock),
                   get_items=get_image_files,
                   splitter=RandomSplitter(seed=672),
                   get_y=get_y,
                   item_tfms=Resize(200),
                   batch_tfms=[*aug_transforms(flip_vert=True, max_zoom=1.2, max_warp=0), Normalize()])

# %%
dls = dblock.dataloaders(path/'cell_images/cell_images', bs=64)

# %%
dls.show_batch()

# %% [markdown]
# # Learner

# %%
dls.c
# Out:
# 2

# %%
model = xResNet(3, dls.c, [2,2,2,2])

# %%
learn= Learner(dls, model, metrics=partial(accuracy_multi, thresh=0.5))

# %%
learn.dls.vocab
# Out:
# ['Parasitized', 'Uninfected']

# %%
learn.loss_func
# Out:
# FlattenedLoss of BCEWithLogitsLoss()

# %%
learn.summary()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# xResNet (Input shape: ['64 x 3 x 200 x 200'])
# ================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ================================================================
# RandHead             64 x 3 x 224 x 224   0          False
# ________________________________________________________________
# Conv2d               64 x 32 x 112 x 112  864        True
# ________________________________________________________________
# BatchNorm2d          64 x 32 x 112 x 112  64         True
# ________________________________________________________________
# ReLU                 64 x 32 x 112 x 112  0          False
# ________________________________________________________________
# Conv2d               64 x 32 x 112 x 112  9,216      True
# ________________________________________________________________
# BatchNorm2d          64 x 32 x 112 x 112  64         True
# ________________________________________________________________
# ReLU                 64 x 32 x 112 x 112  0          False
# ________________________________________________________________
# Conv2d               64 x 64 x 112 x 112  18,432     True
# ________________________________________________________________
# BatchNorm2d          64 x 64 x 112 x 112  128        True
# ________________________________________________________________
# ReLU                 64 x 64 x 112 x 112  0          False
# ________________________________________________________________
# MaxPool2d            64 x 64 x 56 x 56    0          False
# ________________________________________________________________
# Conv2d               64 x 16 x 56 x 56    1,024      True
# ________________________________________________________________
# BatchNorm2d          64 x 16 x 56 x 56    32         True
# ________________________________________________________________
# ReLU                 64 x 16 x 56 x 56    0          False
# ________________________________________________________________
# Conv2d               64 x 16 x 56 x 56    272        True
# ________________________________________________________________
# Conv2d               64 x 16 x 56 x 56    272        True
# ________________________________________________________________
# Conv2d               64 x 16 x 56 x 56    272        True
# ________________________________________________________________
# AvgPool2d            64 x 16 x 28 x 28    0          False
# ________________________________________________________________
# Conv2d               64 x 64 x 28 x 28    1,024      True
# ________________________________________________________________
# BatchNorm2d          64 x 64 x 28 x 28    128        True
# ________________________________________________________________
# AvgPool2d            64 x 64 x 28 x 28    0          False
# ________________________________________________________________
# Conv2d               64 x 16 x 28 x 28    1,024      True
# ________________________________________________________________
# BatchNorm2d          64 x 16 x 28 x 28    32         True
# ________________________________________________________________
# ReLU                 64 x 16 x 28 x 28    0          False
# ________________________________________________________________
# Conv2d               64 x 16 x 28 x 28    272        True
# ________________________________________________________________
# Conv2d               64 x 16 x 28 x 28    272        True
# ________________________________________________________________
# Conv2d               64 x 16 x 28 x 28    272        True
# ________________________________________________________________
# Conv2d               64 x 64 x 28 x 28    1,024      True
# ________________________________________________________________
# BatchNorm2d          64 x 64 x 28 x 28    128        True
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    2,048      True
# ________________________________________________________________
# BatchNorm2d          64 x 32 x 28 x 28    64         True
# ________________________________________________________________
# ReLU                 64 x 32 x 28 x 28    0          False
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    1,056      True
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    1,056      True
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    1,056      True
# ________________________________________________________________
# Conv2d               64 x 128 x 28 x 28   4,096      True
# ________________________________________________________________
# BatchNorm2d          64 x 128 x 28 x 28   256        True
# ________________________________________________________________
# Conv2d               64 x 128 x 28 x 28   8,192      True
# ________________________________________________________________
# BatchNorm2d          64 x 128 x 28 x 28   256        True
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    4,096      True
# ________________________________________________________________
# BatchNorm2d          64 x 32 x 28 x 28    64         True
# ________________________________________________________________
# ReLU                 64 x 32 x 28 x 28    0          False
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    1,056      True
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    1,056      True
# ________________________________________________________________
# Conv2d               64 x 32 x 28 x 28    1,056      True
# ________________________________________________________________
# Conv2d               64 x 128 x 28 x 28   4,096      True
# ________________________________________________________________
# BatchNorm2d          64 x 128 x 28 x 28   256        True
# ________________________________________________________________
# Conv2d               64 x 64 x 28 x 28    8,192      True
# ________________________________________________________________
# BatchNorm2d          64 x 64 x 28 x 28    128        True
# ________________________________________________________________
# ReLU                 64 x 64 x 28 x 28    0          False
# ________________________________________________________________
# Conv2d               64 x 64 x 28 x 28    4,160      True
# ________________________________________________________________
# Conv2d               64 x 64 x 28 x 28    4,160      True
# ________________________________________________________________
# Conv2d               64 x 64 x 28 x 28    4,160      True
# ________________________________________________________________
# AvgPool2d            64 x 64 x 14 x 14    0          False
# ________________________________________________________________
# Conv2d               64 x 256 x 14 x 14   16,384     True
# ________________________________________________________________
# BatchNorm2d          64 x 256 x 14 x 14   512        True
# ________________________________________________________________
# Conv2d               64 x 256 x 14 x 14   32,768     True
# ________________________________________________________________
# BatchNorm2d          64 x 256 x 14 x 14   512        True
# ________________________________________________________________
# AvgPool2d            64 x 128 x 14 x 14   0          False
# ________________________________________________________________
# Conv2d               64 x 64 x 14 x 14    16,384     True
# ________________________________________________________________
# BatchNorm2d          64 x 64 x 14 x 14    128        True
# ________________________________________________________________
# ReLU                 64 x 64 x 14 x 14    0          False
# ________________________________________________________________
# Conv2d               64 x 64 x 14 x 14    4,160      True
# ________________________________________________________________
# Conv2d               64 x 64 x 14 x 14    4,160      True
# ________________________________________________________________
# Conv2d               64 x 64 x 14 x 14    4,160      True
# ________________________________________________________________
# Conv2d               64 x 256 x 14 x 14   16,384     True
# ________________________________________________________________
# BatchNorm2d          64 x 256 x 14 x 14   512        True
# ________________________________________________________________
# Conv2d               64 x 128 x 14 x 14   32,768     True
# ________________________________________________________________
# BatchNorm2d          64 x 128 x 14 x 14   256        True
# ________________________________________________________________
# ReLU                 64 x 128 x 14 x 14   0          False
# ________________________________________________________________
# Conv2d               64 x 128 x 14 x 14   16,512     True
# ________________________________________________________________
# Conv2d               64 x 128 x 14 x 14   16,512     True
# ________________________________________________________________
# Conv2d               64 x 128 x 14 x 14   16,512     True
# ________________________________________________________________
# AvgPool2d            64 x 128 x 7 x 7     0          False
# ________________________________________________________________
# Conv2d               64 x 512 x 7 x 7     65,536     True
# ________________________________________________________________
# BatchNorm2d          64 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# Conv2d               64 x 512 x 7 x 7     131,072    True
# ________________________________________________________________
# BatchNorm2d          64 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# AvgPool2d            64 x 256 x 7 x 7     0          False
# ________________________________________________________________
# Conv2d               64 x 128 x 7 x 7     65,536     True
# ________________________________________________________________
# BatchNorm2d          64 x 128 x 7 x 7     256        True
# ________________________________________________________________
# ReLU                 64 x 128 x 7 x 7     0          False
# ________________________________________________________________
# Conv2d               64 x 128 x 7 x 7     16,512     True
# ________________________________________________________________
# Conv2d               64 x 128 x 7 x 7     16,512     True
# ________________________________________________________________
# Conv2d               64 x 128 x 7 x 7     16,512     True
# ________________________________________________________________
# Conv2d               64 x 512 x 7 x 7     65,536     True
# ________________________________________________________________
# BatchNorm2d          64 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# AdaptiveAvgPool2d    64 x 512 x 1 x 1     0          False
# ________________________________________________________________
# Flatten              64 x 512             0          False
# ________________________________________________________________
# Linear               64 x 2               1,026      True
# ________________________________________________________________
#
# Total params: 645,570
# Total trainable params: 645,570
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7f613fe307a0>
# Loss function: FlattenedLoss of BCEWithLogitsLoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.025118863582611083, lr_steep=0.03981071710586548)

# %%
learn.fit_one_cycle(20, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.466145</td>
#       <td>0.388607</td>
#       <td>0.872528</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.189787</td>
#       <td>0.147676</td>
#       <td>0.952277</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.172740</td>
#       <td>0.139686</td>
#       <td>0.952912</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.169016</td>
#       <td>0.134458</td>
#       <td>0.953820</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.177570</td>
#       <td>0.128067</td>
#       <td>0.957630</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.161684</td>
#       <td>0.128754</td>
#       <td>0.957630</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.154621</td>
#       <td>0.122515</td>
#       <td>0.957177</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.150733</td>
#       <td>0.117121</td>
#       <td>0.960261</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.143954</td>
#       <td>0.109505</td>
#       <td>0.960715</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.148589</td>
#       <td>0.117955</td>
#       <td>0.955906</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.129861</td>
#       <td>0.104558</td>
#       <td>0.963528</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.134184</td>
#       <td>0.102707</td>
#       <td>0.964344</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.122703</td>
#       <td>0.104284</td>
#       <td>0.964253</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.122827</td>
#       <td>0.106504</td>
#       <td>0.962892</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.122271</td>
#       <td>0.096044</td>
#       <td>0.966975</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.122682</td>
#       <td>0.101203</td>
#       <td>0.965886</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.106225</td>
#       <td>0.095003</td>
#       <td>0.966612</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.112447</td>
#       <td>0.093061</td>
#       <td>0.966612</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.100741</td>
#       <td>0.092582</td>
#       <td>0.967882</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.100088</td>
#       <td>0.093791</td>
#       <td>0.967520</td>
#       <td>02:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export('adv_r18.pkl')

# %%
learn.save('adv_r18')
# Out:
# Path('models/adv_r18.pth')

# %%
learn.load('adv_r18');

# %% [markdown]
# Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(figsize=(10, 8))

# %%
preds, y_true=learn.get_preds()
y_true.shape, preds.shape
# Out:
# (torch.Size([5511, 2]), torch.Size([5511, 2]))

# %%
preds = np.argmax(preds.numpy(), axis=-1)
y_true = np.argmax(y_true.numpy(), axis=-1)
y_true.shape, preds.shape
# Out:
# ((5511,), (5511,))

# %%
classes = list(dls.vocab)
report = classification_report(y_true, preds, target_names=classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#  Parasitized       0.98      0.96      0.97      2788
#   Uninfected       0.96      0.98      0.97      2723
#
#     accuracy                           0.97      5511
#    macro avg       0.97      0.97      0.97      5511
# weighted avg       0.97      0.97      0.97      5511

# %%
learn.show_results()

# %% [markdown]
# ## Compare with pure convolutional ResNets

# %%
learn = cnn_learner(dls, resnet18, metrics=accuracy)

# %%
learn.summary()
# Out:
# Sequential (Input shape: ['32 x 3 x 224 x 224'])
# ================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ================================================================
# Conv2d               32 x 64 x 112 x 112  9,408      False
# ________________________________________________________________
# BatchNorm2d          32 x 64 x 112 x 112  128        True
# ________________________________________________________________
# ReLU                 32 x 64 x 112 x 112  0          False
# ________________________________________________________________
# MaxPool2d            32 x 64 x 56 x 56    0          False
# ________________________________________________________________
# Conv2d               32 x 64 x 56 x 56    36,864     False
# ________________________________________________________________
# BatchNorm2d          32 x 64 x 56 x 56    128        True
# ________________________________________________________________
# ReLU                 32 x 64 x 56 x 56    0          False
# ________________________________________________________________
# Conv2d               32 x 64 x 56 x 56    36,864     False
# ________________________________________________________________
# BatchNorm2d          32 x 64 x 56 x 56    128        True
# ________________________________________________________________
# Conv2d               32 x 64 x 56 x 56    36,864     False
# ________________________________________________________________
# BatchNorm2d          32 x 64 x 56 x 56    128        True
# ________________________________________________________________
# ReLU                 32 x 64 x 56 x 56    0          False
# ________________________________________________________________
# Conv2d               32 x 64 x 56 x 56    36,864     False
# ________________________________________________________________
# BatchNorm2d          32 x 64 x 56 x 56    128        True
# ________________________________________________________________
# Conv2d               32 x 128 x 28 x 28   73,728     False
# ________________________________________________________________
# BatchNorm2d          32 x 128 x 28 x 28   256        True
# ________________________________________________________________
# ReLU                 32 x 128 x 28 x 28   0          False
# ________________________________________________________________
# Conv2d               32 x 128 x 28 x 28   147,456    False
# ________________________________________________________________
# BatchNorm2d          32 x 128 x 28 x 28   256        True
# ________________________________________________________________
# Conv2d               32 x 128 x 28 x 28   8,192      False
# ________________________________________________________________
# BatchNorm2d          32 x 128 x 28 x 28   256        True
# ________________________________________________________________
# Conv2d               32 x 128 x 28 x 28   147,456    False
# ________________________________________________________________
# BatchNorm2d          32 x 128 x 28 x 28   256        True
# ________________________________________________________________
# ReLU                 32 x 128 x 28 x 28   0          False
# ________________________________________________________________
# Conv2d               32 x 128 x 28 x 28   147,456    False
# ________________________________________________________________
# BatchNorm2d          32 x 128 x 28 x 28   256        True
# ________________________________________________________________
# Conv2d               32 x 256 x 14 x 14   294,912    False
# ________________________________________________________________
# BatchNorm2d          32 x 256 x 14 x 14   512        True
# ________________________________________________________________
# ReLU                 32 x 256 x 14 x 14   0          False
# ________________________________________________________________
# Conv2d               32 x 256 x 14 x 14   589,824    False
# ________________________________________________________________
# BatchNorm2d          32 x 256 x 14 x 14   512        True
# ________________________________________________________________
# Conv2d               32 x 256 x 14 x 14   32,768     False
# ________________________________________________________________
# BatchNorm2d          32 x 256 x 14 x 14   512        True
# ________________________________________________________________
# Conv2d               32 x 256 x 14 x 14   589,824    False
# ________________________________________________________________
# BatchNorm2d          32 x 256 x 14 x 14   512        True
# ________________________________________________________________
# ReLU                 32 x 256 x 14 x 14   0          False
# ________________________________________________________________
# Conv2d               32 x 256 x 14 x 14   589,824    False
# ________________________________________________________________
# BatchNorm2d          32 x 256 x 14 x 14   512        True
# ________________________________________________________________
# Conv2d               32 x 512 x 7 x 7     1,179,648  False
# ________________________________________________________________
# BatchNorm2d          32 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# ReLU                 32 x 512 x 7 x 7     0          False
# ________________________________________________________________
# Conv2d               32 x 512 x 7 x 7     2,359,296  False
# ________________________________________________________________
# BatchNorm2d          32 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# Conv2d               32 x 512 x 7 x 7     131,072    False
# ________________________________________________________________
# BatchNorm2d          32 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# Conv2d               32 x 512 x 7 x 7     2,359,296  False
# ________________________________________________________________
# BatchNorm2d          32 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# ReLU                 32 x 512 x 7 x 7     0          False
# ________________________________________________________________
# Conv2d               32 x 512 x 7 x 7     2,359,296  False
# ________________________________________________________________
# BatchNorm2d          32 x 512 x 7 x 7     1,024      True
# ________________________________________________________________
# AdaptiveAvgPool2d    32 x 512 x 1 x 1     0          False
# ________________________________________________________________
# AdaptiveMaxPool2d    32 x 512 x 1 x 1     0          False
# ________________________________________________________________
# Flatten              32 x 1024            0          False
# ________________________________________________________________
# BatchNorm1d          32 x 1024            2,048      True
# ________________________________________________________________
# Dropout              32 x 1024            0          False
# ________________________________________________________________
# Linear               32 x 512             524,288    True
# ________________________________________________________________
# ReLU                 32 x 512             0          False
# ________________________________________________________________
# BatchNorm1d          32 x 512             1,024      True
# ________________________________________________________________
# Dropout              32 x 512             0          False
# ________________________________________________________________
# Linear               32 x 2               1,024      True
# ________________________________________________________________
#
# Total params: 11,704,896
# Total trainable params: 537,984
# Total non-trainable params: 11,166,912
#
# Optimizer used: <function Adam at 0x7f6262758050>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group number 2
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ## Explainability with Grad CAM

# %%
class Hook():
    def __init__(self, m):
        self.hook = m.register_forward_hook(self.hook_func)   
    def hook_func(self, m, i, o): self.stored = o.detach().clone()
    def __enter__(self, *args): return self
    def __exit__(self, *args): self.hook.remove()

# %%
class HookBwd():
    def __init__(self, m):
        self.hook = m.register_backward_hook(self.hook_func)
    def hook_func(self, m, gi, go): self.stored = go[0].detach().clone()
    def __enter__(self, *args): return self
    def __exit__(self, *args): self.hook.remove()

# %%
xb, yb = first(dls.valid)

# %%
xb.shape, yb.shape
# Out:
# (torch.Size([64, 3, 200, 200]), torch.Size([64, 2]))

# %%
inp = xb[0][None,...]
inp.shape
# Out:
# torch.Size([1, 3, 200, 200])

# %%
cls = 0
with HookBwd(learn.model[-4]) as hookg:
    with Hook(learn.model[-4]) as hook:
        output = learn.model.eval()(inp.cpu())
        print(output.shape)
        act = hook.stored
    output[0,cls].backward()
    grad = hookg.stored
# Out:
# torch.Size([1, 2])

# %%
w = grad[0].mean(dim=[1,2], keepdim=True)
cam_map = (w * act[0]).sum(0)

# %%
inp_dec = TensorImage(dls.train.decode((inp,))[0][0])

# %%
_,ax = plt.subplots()
inp_dec.show(ctx=ax)
ax.imshow(cam_map.detach().cpu(), alpha=0.6, extent=(0,200,200,0),
              interpolation='bilinear', cmap='magma');
