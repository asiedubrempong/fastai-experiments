# %% [markdown]
# # Modified Implementation of Full-Resolution Resdual Networks (FRRN) for Semantic Segmentation in Street Scenes
# ---
# - Instead of using bilinear interpolation as in the original paper, upsampling is done using PixleShuffleICNR
#
# Link to paper on [arxiv](https://arxiv.org/abs/1611.08323)

# %%
from fastai2.vision.all import *

# %% [markdown]
# ## Data

# %%
path = untar_data(URLs.CAMVID)
Path.BASE_PATH = path
path.ls()
# Out:
# (#5) [Path('codes.txt'),Path('images'),Path('valid.txt'),Path('models'),Path('labels')]

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str)
codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car',
#        'CartLuggagePram', 'Child', 'Column_Pole', 'Fence', 'LaneMkgsDriv',
#        'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving',
#        'ParkingBlock', 'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk',
#        'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel',
#        'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %%
valid_files = (path/'valid.txt').read().split('\n')
len(valid_files)
# Out:
# 102

# %%
def ListSplitter(valid_files):
    """
    Split images into training and validation set using the list of validation files provided
    """
    def _inner(files):
        val_mask = tensor([o.name in valid_files for o in files])
        return [~val_mask, val_mask]
    return _inner

# %%
def get_y(file):
    """
    Get the path to the mask for a particular image
    """
    return path/'labels'/f'{file.stem}_P{file.suffix}'

# %%
imsize=(360,480)

# %%
dblock = DataBlock(
    blocks=(ImageBlock, MaskBlock(codes=codes)),
    get_items=get_image_files,
    splitter=ListSplitter(valid_files),
    get_y=get_y,
    batch_tfms=[*aug_transforms(size=imsize), Normalize()])

# %%
dls = dblock.dataloaders(path/'images', bs=1)
dls.show_batch()

# %%
dls.vocab = codes

# %% [markdown]
# ## FRRN Implementation
# ---
# An FRRN is composed of a sequence of full-resolution residual units (FRRUs).

# %% [markdown]
# ### FRRU Module
#
# ![ffru design](frru.png)

# %%
class FRRU(Module):
    def __init__(self, psc, rsc, scale, nf):
        """
        psc= number of channels in pooling stream input
        rsc= number of channels in residual stream input
        """
        self.mp = nn.MaxPool2d(scale, scale)
        self.conv1 = ConvLayer(psc+rsc, nf)
        self.conv2 = ConvLayer(nf, nf)
        self.res_conv = ConvLayer(nf, rsc, ks=1, bias=True, norm_type=None, act_cls=None)
        
    def forward(self, inp):
        y, z = inp
        z_n = self.mp(z)
        
        if z_n.shape[-2:] != y.shape:
            y = F.interpolate(y, size=z_n.shape[-2:], mode='nearest')
        x = torch.cat([y, z_n], dim=1)
        
        y_n = self.conv2(self.conv1(x)) # output for the pooling stream
        # output for the residual stream
        x = F.interpolate(self.res_conv(y_n), size=z.shape[-2:],
                            mode='nearest')
        z_n = z + x
        
        return y_n, z_n

# %% [markdown]
# The authors of the paper designed two FRRN architectures to assess their approach’s segmentation performance. Depending on the input image resolution, they use FRRN A or FRRN B to keep the relative size of the receptive fields consistent.

# %%
frrn_specs = {
    'a': {'encoder': [[2,3,96], [4,4,192], 
                      [8,2,384], [16,2,384]],
          'decoder': [[8,2,192], [4,2,192],[2,2,96]]
    },
    'b': {'encoder': [[2,3,96], [4,4,192], [8,2,384],
                      [16,2,384], [32,2,384]],
          'decoder': [[16,2,192], [8,2,192], 
                      [4,2,192], [2,2,96]]
    }
}

# %% [markdown]
# Each `[x,y,z]` pair is the *scale* (how much the residual input needs to be scaled in order to match the corresponding pooling stream input), *the number of ffru's and the number of output feature maps* for a particular block in the network.

# %%
class FRRUBlock(nn.Sequential):
    def __init__(self, psc, rsc, scale, ns, nf):
        layers = []
        for _ in range(ns):
            layers.append(FRRU(psc, rsc, scale, nf))
            psc=nf
        
        super().__init__(*layers)

# %%
class FRRN(Module):
    def __init__(self, n_classes, arch='a', n_in=3):
        frrn = frrn_specs[arch]
        
        # the first two layers are the same for each type of architecture
        ru = [ResBlock(1,48,48 ) for _ in range(3)]
        self.stem = nn.Sequential(ConvLayer(3, 48, ks=5), *ru)
        
        psc, rsc = 48, 32
        self.encoder = nn.ModuleList()
        for specs in frrn['encoder']:
            block = FRRUBlock(psc, rsc, *specs)
            self.encoder.append(block)
            psc = specs[2]

        self.decoder = nn.ModuleList()
        for specs in frrn['decoder']:
            upsample = PixelShuffle_ICNR(psc)
            block = FRRUBlock(psc, rsc, *specs)
            
            self.decoder.extend([upsample, block])
            psc = specs[2]
            
        # final upsampling layer
        self.decoder.append(PixelShuffle_ICNR(psc))
            
        ru = [ResBlock(1,48,48 ) for _ in range(2)]
        self.head = nn.Sequential(
            ResBlock(1,psc+rsc,48),
            *ru,
            ConvLayer(48,n_classes,ks=1,bias=True,norm_type=None,act_cls=None))
        
        self.mp = nn.MaxPool2d(2,2)
        self.res_conv = ConvLayer(48, 32, ks=1, norm_type=None, act_cls=None)
        
    def forward(self, x):
        x = self.stem(x)
        y = x # pooling stream
        z = self.res_conv(x) # residual stream
        
        sizes = []
        # forward pass through encoder
        for block in self.encoder:
            # keep track of the shapes of the feature maps before the max pool is applied
            # so that the decoder can upsample to the same shape
            sizes.append(y.shape[-2:])
            y = self.mp(y) # max pool
            y, z = block((y,z))
               
        # forward pass through decoder
        for block in self.decoder:
            y, z = block((y,z))
        
        if y.shape[-2] != z.shape[-2:]:
            y = F.interpolate(y, size=z.shape[-2:], mode='nearest')
            
        # concatenate
        x = torch.cat([y,z], dim=1)
        x = self.head(x)
        return x

# %% [markdown]
# ## Train the model

# %% [markdown]
# Define accuracy metric for camvid

# %%
val2idx = L([code for code in codes]).val2idx()
void_code = val2idx['Void']
void_code
# Out:
# 30

# %%
def acc_camvid(pred, targ):
    print(targ.shape)
    mask = targ != void_code
    return (pred.argmax(dim=1)[mask] == targ[mask]).float().mean()

# %%
model = FRRN(get_c(dls))

# %%
device = torch.device('cuda')
device
# Out:
# device(type='cuda')

# %%
model.to(device);

# %%
learn = Learner(dls, model, metrics=acc_camvid)

# %%
learn.summary()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-bc39e9e85f86> in <module>
# ----> 1 learn.summary()
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/fastai2/callback/hook.py in summary(self)
#     186     "Print a summary of the model, optimizer and loss function."
#     187     xb = self.dls.train.one_batch()[:self.dls.train.n_inp]
# --> 188     res = self.model.summary(*xb)
#     189     res += f"Optimizer used: {self.opt_func}\nLoss function: {self.loss_func}\n\n"
#     190     if self.opt is not None:
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/fastai2/callback/hook.py in summary(self, *xb)
#     161 def summary(self:nn.Module, *xb):
#     162     "Print a summary of `self` using `xb`"
# --> 163     sample_inputs,infos = layer_info(self, *xb)
#     164     n,bs = 64,find_bs(xb)
#     165     inp_sz = _print_shapes(apply(lambda x:x.shape, xb), bs)
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/fastai2/callback/hook.py in layer_info(model, *xb)
#     149     layers = [m for m in flatten_model(model)]
#     150     with Hooks(layers, _track) as h:
# --> 151         _ = model.eval()(*apply(lambda o:o[:1], xb))
#     152         return xb,h.stored
#     153
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-14-bc092f94c4fa> in forward(self, x)
#      35
#      36     def forward(self, x):
# ---> 37         x = self.stem(x)
#      38         y = x # pooling stream
#      39         z = self.res_conv(x) # residual stream
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/fastai2/layers.py in forward(self, x)
#     557         self.act = defaults.activation(inplace=True) if act_cls is defaults.activation else act_cls()
#     558
# --> 559     def forward(self, x): return self.act(self.convpath(x) + self.idpath(x))
#     560
#     561 # Cell
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     105             input, self.running_mean, self.running_var, self.weight, self.bias,
#     106             self.training or not self.track_running_stats,
# --> 107             exponential_average_factor, self.eps)
#     108
#     109
#
# /opt/conda/envs/fastai/lib/python3.7/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1668     return torch.batch_norm(
#    1669         input, weight, bias, running_mean, running_var,
# -> 1670         training, momentum, eps, torch.backends.cudnn.enabled
#    1671     )
#    1672
#
# RuntimeError: CUDA out of memory. Tried to allocate 32.00 MiB (GPU 0; 15.90 GiB total capacity; 617.98 MiB already allocated; 16.50 MiB free; 632.00 MiB reserved in total by PyTorch)

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(5, 3e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='150', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/150 00:00<00:00]
#     </div>
